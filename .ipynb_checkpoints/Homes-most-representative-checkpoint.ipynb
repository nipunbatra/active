# %% [markdown]
# ### Question: If we don't normalise do we get all from HVAC for active learning

# %%
# !pip install autograd
# Out:
# Collecting autograd
#   Downloading https://files.pythonhosted.org/packages/08/7a/1ccee2a929d806ba3dbe632a196ad6a3f1423d6e261ae887e5fef2011420/autograd-1.2.tar.gz
# Requirement already satisfied: numpy>=1.12 in /Users/nipun/anaconda3/lib/python3.6/site-packages (from autograd)
# Collecting future>=0.15.2 (from autograd)
#   Downloading https://files.pythonhosted.org/packages/00/2b/8d082ddfed935f3608cc61140df6dcbf0edea1bc3ab52fb6c29ae3e81e85/future-0.16.0.tar.gz (824kB)
#     100% |████████████████████████████████| 829kB 811kB/s ta 0:00:01
# Building wheels for collected packages: autograd, future
#   Running setup.py bdist_wheel for autograd ... done
#   Stored in directory: /Users/nipun/Library/Caches/pip/wheels/72/6f/c2/40f130cca2c91f31d354bf72de282922479c09ce0b7853c4c5
#   Running setup.py bdist_wheel for future ... done
#   Stored in directory: /Users/nipun/Library/Caches/pip/wheels/bf/c9/a3/c538d90ef17cf7823fa51fc701a7a7a910a80f6a405bf15b1a
# Successfully built autograd future
# Installing collected packages: future, autograd
# Successfully installed autograd-1.2 future-0.16.0
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import autograd.numpy as np
from autograd import grad
import pandas as pd
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Loading the dataset

# %%
d = np.load("/Users/nipun/Downloads/data-2013-2017-missing.npy").item()

# %% [markdown]
# #### Finding homes occuring across both years

# %%
np.intersect1d(list(d[2016].keys()), list(d[2015].keys())).size
# Out:
# 214

# %%
np.intersect1d(list(d[2017].keys()), list(d[2016].keys())).size
# Out:
# 153

# %% [markdown]
# I would be choosing 2015 and 2016 as the successive years

# %%
use_homes = np.intersect1d(list(d[2016].keys()), list(d[2015].keys()))

# %%
use_homes
# Out:
# array([  26,   59,   77,   86,   93,   94,  101,  114,  187,  434,  484,
#         499,  503,  545,  624,  744,  781,  871,  946,  974, 1086, 1103,
#        1169, 1192, 1202, 1283, 1403, 1415, 1463, 1500, 1507, 1589, 1617,
#        1632, 1642, 1697, 1700, 1718, 1790, 1800, 1953, 2018, 2094, 2129,
#        2156, 2171, 2199, 2233, 2365, 2378, 2472, 2532, 2557, 2575, 2638,
#        2755, 2787, 2814, 2818, 2829, 2859, 2945, 2953, 2965, 3009, 3039,
#        3044, 3134, 3268, 3310, 3367, 3392, 3456, 3482, 3500, 3527, 3538,
#        3577, 3649, 3778, 3829, 3831, 3849, 3916, 3918, 3935, 3967, 4031,
#        4154, 4213, 4220, 4297, 4298, 4336, 4342, 4352, 4357, 4373, 4375,
#        4473, 4514, 4641, 4767, 4874, 4946, 4957, 4998, 5026, 5060, 5129,
#        5218, 5275, 5317, 5357, 5403, 5545, 5568, 5677, 5718, 5785, 5809,
#        5814, 5874, 5889, 5921, 5949, 5959, 5972, 6061, 6063, 6121, 6139,
#        6165, 6348, 6412, 6423, 6460, 6498, 6691, 6692, 6730, 6990, 7016,
#        7030, 7361, 7390, 7429, 7504, 7536, 7560, 7627, 7641, 7719, 7731,
#        7769, 7787, 7788, 7793, 7850, 7875, 7900, 7901, 7940, 7951, 7973,
#        7989, 8046, 8059, 8079, 8084, 8086, 8092, 8156, 8163, 8197, 8236,
#        8243, 8292, 8317, 8386, 8419, 8645, 8767, 8807, 8829, 8995, 9001,
#        9019, 9052, 9121, 9134, 9141, 9160, 9248, 9356, 9484, 9609, 9613,
#        9647, 9654, 9701, 9729, 9771, 9875, 9912, 9915, 9922, 9932, 9935,
#        9937, 9938, 9942, 9971, 9982])

# %%
APPLIANCE_ORDER = ['use','air1','dishwasher1','furnace1','kitchenapp1','microwave1','refrigerator1']

# %% [markdown]
# ### Creating the tensor data

# %%
t = np.empty((len(use_homes), len(APPLIANCE_ORDER), 2*12))

# %%
t[:] = np.NaN

# %%
for i, home in enumerate(use_homes):
    for j, appliance in enumerate(APPLIANCE_ORDER):
        try:
            t[i, j, :12] = d[2016][home][appliance].values
            t[i, j, 12:] = d[2017][home][appliance].values
        except:
            pass

# %%
t.shape
# Out:
# (214, 7, 24)

# %% [markdown]
# ### STF routine

# %%
def factorise(tensor, r, random_seed=0, num_iter=400, eps=1e-8, lr=1):
    np.random.seed(random_seed)
    args_num = [1, 2, 3]

    def cost(tensor, home, appliance,  month):
        pred = np.einsum('Hr, Ar, Tr ->HAT', home, appliance, month)
        mask = ~np.isnan(tensor)
        error = (pred - tensor)[mask].flatten()
        return np.sqrt((error ** 2).mean())

    mg = grad(cost, argnum=args_num)
    sizes = [(x, r) for x in tensor.shape]
    home = np.random.rand(*sizes[0])
    appliance = np.random.rand(*sizes[1])
    month = np.random.rand(*sizes[2])

    sum_home = np.zeros_like(home)
    sum_appliance = np.zeros_like(appliance)
    sum_month = np.zeros_like(month)

    # GD procedure
    for i in range(num_iter):
        del_home, del_appliance, del_month = mg(tensor, home, appliance, month)

        sum_home += eps + np.square(del_home)
        lr_home = np.divide(lr, np.sqrt(sum_home))
        home -= lr_home * del_home

        sum_appliance += eps + np.square(del_appliance)
        lr_appliance = np.divide(lr, np.sqrt(sum_appliance))
        appliance -= lr_appliance * del_appliance

        sum_month += eps + np.square(del_month)
        lr_month = np.divide(lr, np.sqrt(sum_month))
        month -= lr_month * del_month

        
        # Projection to non-negative space
        home[home < 0] = 1e-8
        appliance[appliance < 0] = 1e-8
        month[month < 0] = 1e-8

        if i % 500 == 0:
            #print(cost(tensor, home, appliance, month), i)
            sys.stdout.flush()

    return home, appliance, month

# %% [markdown]
# #### Creating the different subsets if data

# %%
# Test is last 44 homes
test_set = t[170:].copy()
# In test set, we don't know the appliance data
test_set[:, 1:, :] = np.NaN
# Train + Pool is the remaining set
train_pool_set = t[:170].copy()
# Initial train set is 10 homes
train_set = t[:10].copy()
# Initial pool set is 10-170 homes
pool_set = t[10:170].copy()
pool_homes = use_homes[10:170]
# Train + Test set (useful for factorisation)
train_test_set = np.vstack([train_set, test_set])

# %% [markdown]
# ### Creating the set of (home, appliance) pairs for each month that can contain data and thus can be used for acquiring labels

# %%
p_m_h = {}
for month in range(12, 24):
    p_m_h[month] = []
    for home in pool_homes:
        for i, appliance in enumerate(APPLIANCE_ORDER[1:]):
            pool_home_index  = np.searchsorted(use_homes, home)
            if np.isfinite(t[pool_home_index, i+1, month]):
                p_m_h[month].append((home, appliance))

# %%
p_m_h[12]
#  (7641, 'microwave1'),
#  (7641, 'refrigerator1'),
#  (7731, 'air1'),
#  (7769, 'air1'),
#  (7769, 'dishwasher1'),
#  (7769, 'refrigerator1'),
#  (7787, 'air1'),
#  (7787, 'furnace1'),
#  (7787, 'microwave1'),
#  (7787, 'refrigerator1'),
#  (7788, 'air1'),
#  (7788, 'dishwasher1'),
#  (7788, 'furnace1'),
#  (7788, 'refrigerator1'),
#  (7850, 'air1'),
#  (7850, 'dishwasher1'),
#  (7850, 'furnace1'),
#  (7850, 'kitchenapp1'),
#  (7850, 'microwave1'),
#  (7850, 'refrigerator1'),
#  (7875, 'air1'),
#  (7875, 'furnace1'),
#  (7875, 'microwave1'),
#  (7875, 'refrigerator1'),
#  (7900, 'air1'),
#  (7940, 'air1'),
#  (7940, 'dishwasher1'),
#  (7940, 'furnace1'),
#  (7940, 'kitchenapp1'),
#  (7940, 'microwave1'),
#  (7940, 'refrigerator1'),
#  (7951, 'air1'),
#  (7951, 'dishwasher1'),
#  (7951, 'furnace1'),
#  (7951, 'kitchenapp1'),
#  (7951, 'microwave1'),
#  (7951, 'refrigerator1'),
#  (7973, 'air1'),
#  (7989, 'air1'),
#  (7989, 'furnace1'),
#  (7989, 'microwave1'),
#  (8046, 'air1'),
#  (8046, 'dishwasher1'),
#  (8046, 'furnace1'),
#  (8046, 'kitchenapp1'),
#  (8046, 'microwave1'),
#  (8046, 'refrigerator1'),
#  (8059, 'air1'),
#  (8059, 'dishwasher1'),
#  (8059, 'furnace1'),
#  (8059, 'kitchenapp1'),
#  (8059, 'microwave1'),
#  (8059, 'refrigerator1'),
#  (8079, 'air1'),
#  (8079, 'dishwasher1'),
#  (8079, 'furnace1'),
#  (8079, 'kitchenapp1'),
#  (8079, 'microwave1'),
#  (8079, 'refrigerator1'),
#  (8084, 'air1')]

# %% [markdown]
# #### Randomly adding 5 homes every month from Pool

# %%
pred_df_random = {}
from copy import deepcopy
for seed in range(10):
    print("*-*-*"*20)
    print(seed)
    pool_use = np.empty((0, 7, 24))
    pool_set_iter = deepcopy(p_m_h)
    pred_df_random[seed] = {}
    pool_remove_ix = {}
    pool_remove = {}
    gt_df = {}

    for cur_iteration, month in enumerate(range(12, 24)):
        np.random.seed(seed)
        # Randomly choose `n` to remove from pool and put in training set
        pool_remove_ix[cur_iteration] = np.random.choice(range(len(pool_set_iter[month])), size=5)
        pool_remove[month] = [pool_set_iter[month][x] for x in pool_remove_ix[cur_iteration]]

        # Remove these from future months pool too
        for month_f in range(month+1, 24):
            for x in pool_remove[month]:
                if x in pool_set_iter[month_f]:
                    pool_set_iter[month_f].remove(x)


        # Getting data from `t` to create the pool_use_set
        pool_remove_homes = [x[0] for x in pool_remove[month]]
        pool_remove_homes_ix = np.searchsorted(use_homes, pool_remove_homes)

        cur_pool = t[pool_remove_homes_ix, :, :].copy()
        # All past data is unknown
        cur_pool[:, 1:, :month] = np.NaN

        # All future data for all appliances except the chosen one is known
        cur_pool[:, 1:, month:] = np.NaN
        for q, h in enumerate(pool_remove_homes_ix):
            appliance_num = APPLIANCE_ORDER.index(pool_remove[month][q][1])
            cur_pool[q, appliance_num, month:] = t[h, appliance_num, month:]

        pool_use = np.concatenate([pool_use, cur_pool])

        pool_train_test = np.concatenate([pool_use, train_test_set[:, :, :] ])

        h, a, m =factorise(pool_train_test[:, :, :month], 3)
        print(cur_iteration, month, len(pool_train_test), pool_remove[month])

        pred = np.einsum('Hr, Ar, Tr ->HAT', h, a, m)
        pred_df_random[seed][month] = pred[len(train_set)+len(pool_use):,1:, month-1:month].reshape(-1, len(APPLIANCE_ORDER)-1)
        gt_df[month] = t[170:][:, 1:, month-1:month].reshape(len(test_set), len(APPLIANCE_ORDER)-1)
# Out:
# *-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-*
# 0
# 0 12 59 [(4298, 'microwave1'), (1500, 'dishwasher1'), (2965, 'kitchenapp1'), (4998, 'kitchenapp1'), (7875, 'microwave1')]
# 1 13 64 [(4375, 'air1'), (1500, 'furnace1'), (2965, 'refrigerator1'), (5026, 'dishwasher1'), (7940, 'furnace1')]
# 2 14 69 [(4375, 'refrigerator1'), (1500, 'kitchenapp1'), (3134, 'air1'), (5218, 'air1'), (7951, 'dishwasher1')]
# 3 15 74 [(4514, 'furnace1'), (1500, 'microwave1'), (3367, 'air1'), (5218, 'refrigerator1'), (7973, 'air1')]
# 4 16 79 [(4946, 'air1'), (1500, 'refrigerator1'), (3367, 'furnace1'), (5275, 'kitchenapp1'), (8046, 'dishwasher1')]
# 5 17 84 [(4946, 'microwave1'), (1507, 'air1'), (3367, 'refrigerator1'), (5317, 'dishwasher1'), (8059, 'air1')]
# 6 18 89 [(4998, 'dishwasher1'), (1507, 'dishwasher1'), (3392, 'kitchenapp1'), (5545, 'kitchenapp1'), (8079, 'kitchenapp1')]
# 7 19 94 [(4998, 'refrigerator1'), (1507, 'furnace1'), (3392, 'refrigerator1'), (5677, 'furnace1'), (7429, 'air1')]
# 8 20 99 [(5026, 'kitchenapp1'), (1507, 'kitchenapp1'), (3482, 'dishwasher1'), (5809, 'furnace1'), (7560, 'kitchenapp1')]
# 9 21 104 [(5218, 'kitchenapp1'), (1507, 'microwave1'), (3482, 'microwave1'), (5814, 'furnace1'), (7627, 'furnace1')]
# 10 22 109 [(5317, 'air1'), (1507, 'refrigerator1'), (3500, 'air1'), (5921, 'dishwasher1'), (7641, 'dishwasher1')]
# 11 23 114 [(5545, 'dishwasher1'), (1632, 'air1'), (3500, 'furnace1'), (5949, 'furnace1'), (7769, 'refrigerator1')]
# *-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-*
# 1
# 0 12 59 [(1202, 'air1'), (5921, 'air1'), (2156, 'furnace1'), (6139, 'dishwasher1'), (5218, 'microwave1')]
# 1 13 64 [(1202, 'dishwasher1'), (5921, 'microwave1'), (2156, 'refrigerator1'), (6165, 'furnace1'), (5275, 'dishwasher1')]
# 2 14 69 [(1202, 'furnace1'), (5949, 'furnace1'), (2171, 'dishwasher1'), (6460, 'dishwasher1'), (5275, 'microwave1')]
# 3 15 74 [(1415, 'air1'), (6061, 'air1'), (2171, 'kitchenapp1'), (6691, 'air1'), (5317, 'dishwasher1')]
# 7 19 94 [(3831, 'kitchenapp1'), (3849, 'dishwasher1'), (5545, 'kitchenapp1'), (1500, 'microwave1'), (2472, 'dishwasher1')]
# 8 20 99 [(3849, 'furnace1'), (3849, 'refrigerator1'), (5677, 'kitchenapp1'), (1500, 'refrigerator1'), (2472, 'kitchenapp1')]
# 9 21 104 [(3967, 'air1'), (3967, 'microwave1'), (5809, 'refrigerator1'), (1507, 'air1'), (2532, 'dishwasher1')]
# 10 22 109 [(3967, 'refrigerator1'), (4213, 'furnace1'), (5921, 'air1'), (1507, 'dishwasher1'), (2532, 'microwave1')]
# 11 23 114 [(4213, 'microwave1'), (4298, 'air1'), (5949, 'kitchenapp1'), (1507, 'furnace1'), (2557, 'air1')]
# *-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-**-*-*
# 9
# 0 12 59 [(8059, 'air1'), (3367, 'microwave1'), (1507, 'microwave1'), (6063, 'kitchenapp1'), (3367, 'furnace1')]
# 1 13 64 [(8059, 'refrigerator1'), (3392, 'kitchenapp1'), (1507, 'refrigerator1'), (6139, 'dishwasher1'), (3392, 'furnace1')]
# 2 14 69 [(8079, 'microwave1'), (3482, 'air1'), (1632, 'air1'), (6165, 'dishwasher1'), (3392, 'refrigerator1')]
# 3 15 74 [(3482, 'microwave1'), (1632, 'dishwasher1'), (6423, 'air1'), (3482, 'furnace1'), (1953, 'refrigerator1')]
# 4 16 79 [(3500, 'furnace1'), (1632, 'furnace1'), (6460, 'microwave1'), (3500, 'dishwasher1'), (2156, 'air1')]
# 5 17 84 [(3649, 'air1'), (1632, 'kitchenapp1'), (7016, 'air1'), (3527, 'air1'), (2156, 'furnace1')]
# 6 18 89 [(3778, 'furnace1'), (1632, 'microwave1'), (7429, 'air1'), (3778, 'air1'), (2156, 'refrigerator1')]
# 7 19 94 [(3831, 'kitchenapp1'), (1632, 'refrigerator1'), (7560, 'kitchenapp1'), (3831, 'dishwasher1'), (2171, 'dishwasher1')]
# 8 20 99 [(3849, 'furnace1'), (1718, 'air1'), (7627, 'furnace1'), (3849, 'dishwasher1'), (2171, 'kitchenapp1')]
# 9 21 104 [(3967, 'air1'), (1800, 'air1'), (7641, 'dishwasher1'), (3849, 'refrigerator1'), (2171, 'refrigerator1')]
# 10 22 109 [(3967, 'refrigerator1'), (1953, 'air1'), (7731, 'air1'), (3967, 'microwave1'), (2199, 'dishwasher1')]
# 11 23 114 [(4213, 'microwave1'), (1953, 'furnace1'), (7788, 'dishwasher1'), (4213, 'furnace1'), (2199, 'refrigerator1')]

# %% [markdown]
# ### Active learning Testing

# %%
pool_use = np.empty((0, 7, 24))
gt_df = {}
pred_df_active = {}
pool_remove_active = {}
pool_set_active = {}
all_seen = []

for cur_iteration, month in enumerate(range(12, 13)):
    

    pred_pool = {}
    psc = pool_set.copy()
    psc[:, 1:, :] = np.NaN
    month_contri = (pd.DataFrame(train_set[:, :, month]).mean()/pd.DataFrame(train_set[:, :, month]).mean()[0]).drop(0).to_dict()
    # Starting with current data and finding the variance amongst different #Latent factors
# 141  1078.834130  1217.304691  1223.069576  1267.300438  1234.279277
# 142  1754.265707  1221.256858  1277.278019  1619.876891  1550.129403
# 143   479.916935   455.925812   488.692813   537.763939   565.546900
# 144   316.481287   367.353609   374.754275   366.311072   385.682916
# 145   835.484912   946.438947   955.993097   917.834670   933.224750
# 146  1713.140727  1792.789828  1797.040620  1827.889740  1818.638855
# 147  1312.849451   961.450999   981.778487  1019.473782  1008.443318
# 148   873.400963   860.918578   866.012121   900.649325   864.600151
# 149  1259.877212  1464.820549  1443.841953  1476.326228  1563.290014
# 150  1147.890655  1145.213778  1147.660907  1182.635595  1189.361336
# 151   985.653964  1027.430431  1006.015317   981.777414  1091.549811
# 152  1093.710013  1243.010219  1222.290464  1297.605802  1236.235556
# 153   766.203333   961.812069   989.603127  1023.531941  1043.980539
# 154   922.637699   844.994999   828.996117   934.500048   955.206552
# 155  1024.812830  1028.674532  1014.405335   984.604272   962.503356
# 156  1199.356466  1125.733351  1133.029150  1116.898594  1085.277136
# 157   512.919836   478.382489   486.650647   486.008716   515.949881
# 158  1813.878349  1858.182076  1878.434515  1907.160712  1939.844541
# 159   879.004143  1033.128961  1001.983282   799.998040   929.256318
#
#                7
# 0     688.342444
# 1    1341.765630
# 2    1099.587563
# 3    1063.927532
# 4     863.642233
# 5     589.689228
# 6     744.575143
# 7     825.694307
# 8     514.643566
# 9    1270.953697
# 10    719.921268
# 11    371.037170
# 12    629.864650
# 13    575.298948
# 14   1606.400483
# 15    974.456830
# 16    567.950746
# 17    613.537924
# 18    822.438768
# 19    443.851118
# 20   2981.775137
# 21   1066.398135
# 22   1012.732776
# 23    904.875892
# 24    729.798400
# 25   1654.441420
# 26   1735.668361
# 27   1461.424473
# 28   1706.405007
# 29    991.057722
# ..           ...
# 130   790.626821
# 131   703.064457
# 132  2017.170029
# 133   587.212022
# 134   733.599447
# 135   410.541105
# 136   646.992734
# 137   686.659648
# 138   781.285093
# 139   867.093016
# 140   820.060303
# 141  1252.497958
# 142  1812.279480
# 143   483.009527
# 144   398.859467
# 145   914.023669
# 146  1809.053416
# 147  1083.425464
# 148   857.662465
# 149  1568.090696
# 150  1221.792938
# 151  1135.996386
# 152  1272.449510
# 153  1050.662633
# 154   990.536843
# 155   993.376659
# 156  1116.434690
# 157   513.635382
# 158  1981.655561
# 159   989.465665
#
# [160 rows x 6 columns]

# %%
# Finding the top-most `n` highly variance homes
# measure = std/contri
temp = []
for appliance_num, appliance in enumerate(APPLIANCE_ORDER[1:]):
    y = pd.DataFrame({r:pd.Series(pred_pool[r][:, appliance_num+1, -1])for r in range(2, 8)}).std(axis=1)
    y.index = [(x, appliance) for x in pool_homes]
    #y = (y - y.min())/(y.max()-y.min())
    temp.append(y)

print(pd.concat(temp).sort_values(ascending=False).drop(all_seen).head(10))
# Out:
# (4336, air1)    274.138407
# (3918, air1)    191.254116
# (5357, air1)    190.407229
# (1507, air1)    170.708087
# (7719, air1)    169.768311
# (3044, air1)    152.165705
# (3500, air1)    144.816484
# (6691, air1)    130.561656
# (7016, air1)    130.103196
# (2472, air1)    129.830478
# dtype: float64

# %%
q = (pd.concat(temp).sort_values(ascending=False).drop(all_seen))

# %%
q.index= [x[1] for x in q.index]
z = q.index

# %%
l = {x:pd.value_counts(z[:x]).div(x) for x in range(10, 160*6, 10)}
pd.DataFrame(l).T.plot(kind='line')
plt.xlabel("Top-K by std. deviation")
plt.ylabel("Fraction")
plt.savefig("top-k-std.pdf")

# %%
import matplotlib.pyplot as plt

# %%
pool_set[1, 1, :]
# Out:
# array([   0.        ,    0.        ,    0.99532795,   35.67173767,
#         157.40673828,  486.01150513,  699.71569824,  575.28656006,
#         520.62567139,  264.65786743,   39.34695816,    6.19594526,
#           0.        ,    0.        ,    8.12929058,   82.02701569,
#         180.28712463,  565.4019165 ,  853.81469727,  702.6651001 ,
#         448.10568237,  165.92414856,   77.59373474,    8.57880783])

# %%
pool_train[1, 1, :]
# Out:
# array([ nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan])

# %%
pool_use = np.empty((0, 7, 24))
gt_df = {}
pred_df_active = {}
pool_remove_active = {}
pool_set_active = {}
all_seen = []

for cur_iteration, month in enumerate(range(12, 24)):
    
    # Get all the homes from the currently available pool

    pred_pool = {}
    psc = pool_set.copy()
    psc[:, 1:, :] = np.NaN
    month_contri = (pd.DataFrame(train_set[:, :, month]).mean()/pd.DataFrame(train_set[:, :, month]).mean()[0]).drop(0).to_dict()
    # Starting with current data and finding the variance amongst different #Latent factors
    for r in range(2, 8):
        print(month, r)
        pool_train = np.concatenate([psc, train_set[:, :, :] ])
        h, a, m =factorise(pool_train[:, :, :month], r)
        pred_pool[r] = np.einsum('Hr, Ar, Tr ->HAT', h, a, m)[:len(pool_set)]
        
    # Finding the top-most `n` highly variance homes
    # measure = std/contri
    temp = []
    for appliance_num, appliance in enumerate(APPLIANCE_ORDER[1:]):
        y = pd.DataFrame({r:pd.Series(pred_pool[r][:, appliance_num+1, -1])for r in range(2, 8)}).std(axis=1)
        y.index = [(x, appliance) for x in pool_homes]
        #y = (y - y.min())/(y.max()-y.min())
        temp.append(y)
    
    print(pd.concat(temp).sort_values(ascending=False).drop(all_seen).head(10))
        
    pool_remove_active[month] = pd.concat(temp).sort_values(ascending=False).drop(all_seen).head(5).index.tolist() 
    
    all_seen.extend(pool_remove_active[month])
    all_seen = list(set(all_seen))
    
    # Getting data from `t` to create the pool_use_set
    pool_remove_homes_active = [x[0] for x in pool_remove_active[month]]
    pool_remove_homes_active_ix = np.searchsorted(use_homes, pool_remove_homes_active)
    
    cur_pool = t[pool_remove_homes_active_ix, :, :].copy()
    # All past data is unknown
    cur_pool[:, 1:, :month] = np.NaN
    
    # All future data for all appliances except the chosen one is known
    cur_pool[:, 1:, month:] = np.NaN
    for q, h in enumerate(pool_remove_homes_active_ix):
        appliance_num = APPLIANCE_ORDER.index(pool_remove_active[month][q][1])
        cur_pool[q, appliance_num, month:] = t[h, appliance_num, month:]
    
    pool_use = np.concatenate([pool_use, cur_pool])
    
    pool_train_test = np.concatenate([pool_use, train_test_set[:, :, :] ])

    h, a, m =factorise(pool_train_test[:, :, :month], 3)
    print(cur_iteration, month, len(pool_train_test), pool_remove_active[month])
    
    pred = np.einsum('Hr, Ar, Tr ->HAT', h, a, m)
    pred_df_active[month] = pred[len(train_set)+len(pool_use):,1:, month-1:month].reshape(-1, len(APPLIANCE_ORDER)-1)
    gt_df[month] = t[170:][:, 1:, month-1:month].reshape(len(test_set), len(APPLIANCE_ORDER)-1)
# Out:
# 12 2
# 12 3
# 12 4
# 12 5
# 12 6
# 12 7
# (4336, air1)    274.138407
# (3918, air1)    191.254116
# (5357, air1)    190.407229
# (1507, air1)    170.708087
# (7719, air1)    169.768311
# (3044, air1)    152.165705
# (3500, air1)    144.816484
# (6691, air1)    130.561656
# (7016, air1)    130.103196
# (2472, air1)    129.830478
# dtype: float64
# 0 12 59 [(4336, 'air1'), (3918, 'air1'), (5357, 'air1'), (1507, 'air1'), (7719, 'air1')]
# 13 2
# 13 3
# 13 4
# 13 5
# 13 6
# 13 7
# (3916, air1)    207.882059
# (4154, air1)    207.439325
# (6691, air1)    150.397463
# (2365, air1)    133.469206
# (3500, air1)    129.547833
# (1202, air1)    122.295562
# (3310, air1)    113.172361
# (1589, air1)    110.597149
# (484, air1)     108.742875
# (974, air1)     108.516423
# dtype: float64
# 1 13 64 [(3916, 'air1'), (4154, 'air1'), (6691, 'air1'), (2365, 'air1'), (3500, 'air1')]
# 14 2
# 14 3
# 14 4
# 14 5
# 14 6
# 14 7
# (7016, air1)        116.174549
# (2365, furnace1)     86.549464
# (2018, air1)         77.674732
# (5357, furnace1)     73.463836
# (2378, air1)         71.752960
# (4213, air1)         66.539583
# (7793, air1)         65.881811
# (4375, furnace1)     65.798815
# (4767, air1)         64.454835
# (5809, air1)         64.001290
# dtype: float64
# 2 14 69 [(7016, 'air1'), (2365, 'furnace1'), (2018, 'air1'), (5357, 'furnace1'), (2378, 'air1')]
# 15 2
# 15 3
# 15 4
# 15 5
# 15 6
# 15 7
# (7719, furnace1)    99.251459
# (5972, air1)        92.220651
# (3918, furnace1)    91.701416
# (4957, air1)        87.289625
# (974, air1)         86.971972
# (4213, air1)        85.910496
# (4767, air1)        85.269067
# (7793, air1)        82.833978
# (7788, air1)        79.177689
# (4220, air1)        78.990259
# dtype: float64
# 3 15 74 [(7719, 'furnace1'), (5972, 'air1'), (3918, 'furnace1'), (4957, 'air1'), (974, 'air1')]
# 16 2
# 16 3
# 16 4
# 16 5
# 16 6
# 16 7
# (3039, air1)        121.821895
# (4375, air1)        108.949702
# (7641, air1)        103.547266
# (7016, furnace1)    100.531227
# (1697, air1)         94.699871
# (5809, air1)         90.144453
# (1202, air1)         90.121982
# (6691, furnace1)     89.963694
# (7793, air1)         89.634807
# (6412, air1)         88.912693
# dtype: float64
# 4 16 79 [(3039, 'air1'), (4375, 'air1'), (7641, 'air1'), (7016, 'furnace1'), (1697, 'air1')]
# 17 2
# 17 3
# 17 4
# 17 5
# 17 6
# 17 7
# (7627, air1)             120.478610
# (4767, air1)             111.964415
# (7793, air1)             109.248557
# (7788, air1)             105.965079
# (7900, air1)        100.653330
# (2818, air1)         97.636552
# dtype: float64
# 11 23 114 [(6498, 'air1'), (1718, 'air1'), (5972, 'furnace1'), (8079, 'air1'), (6061, 'air1')]

# %%
random_error = {}
#for seed in range(10):
#    random_error[seed] = {}
#    for month in range(13, 24):
#        random_error[seed][month] = (pd.DataFrame(pred_df_random[seed][month])-pd.DataFrame(gt_df[month])).abs().mean()
active_error = {}
for month in range(13, 24):
    active_error[month] = (pd.DataFrame(pred_df_active[month])-pd.DataFrame(gt_df[month])).abs().mean()

# %%
p = pd.Panel(random_error)

# %%
p.mean(axis=0)
# Out:
#            13         14         15          16          17          18  \
# 0  174.727654  98.136005  93.219758  111.226212  135.752091  245.228373
# 1   13.803874  13.123776  15.784423   13.988422   14.527469   14.347852
# 2  121.220506  70.803479  84.794182   99.209682   97.359031  116.056768
# 3   10.012749  11.049360  10.417267   11.031750   11.815385   10.823312
# 4   10.962366   7.622557   7.267819    8.777809    6.926860    7.867399
# 5   38.610597  39.220722  43.054340   41.606648   42.880585   49.331856
#
#            19          20          21          22          23
# 0  275.022541  255.978251  203.255655  168.110451  125.414486
# 1   16.992265   12.366308    9.351721    7.432315    8.081507
# 2  134.336664  128.340326  107.356612   67.897643   67.111920
# 3   10.427257    9.337735    9.760632    9.080830    8.271339
# 4    7.995557    7.609911    7.530294    6.497347    6.425706
# 5   51.551383   47.873996   43.915176   40.206062   39.478151

# %%
pd.DataFrame(active_error)
# Out:
#            13         14         15         16          17          18  \
# 0  146.855394  83.785468  75.036549  98.967695  144.712988  205.099340
# 1   14.483744  15.198674  17.799936  13.377700   20.431925   14.908665
# 2  132.393579  68.088709  95.714145  91.965661   91.460754  135.298847
# 3    9.911026  10.881184  10.261232  10.759155   11.847615   10.533852
# 4    9.400232   7.544331   7.136182   8.744031    5.672035    8.065303
# 5   44.857410  38.596655  43.865048  39.379441   39.262394   51.317519
#
#            19          20          21         22         23
# 0  248.609910  303.159295  206.867355  79.355259  62.736379
# 1   17.503071   16.207103   11.303742   8.930056  11.898893
# 2  147.255459  156.687668  125.594138  69.433499  77.174297
# 3    9.771363    9.626937    9.087010   8.588026   7.882614
# 4    7.797370    7.558782    6.915034   6.604377   5.755610
# 5   48.856022   58.841419   47.606366  37.378304  32.301067

# %%
pd.DataFrame(active_error)
# Out:
#            13         14          15          16          17          18  \
# 0  129.786957  86.714324  167.270344  132.132225  130.058033  183.863019
# 1   15.506828  11.316772   11.024344    9.999262   13.518234   17.154611
# 2  127.678468  67.886351   74.828083   72.925842   69.721794  102.441397
# 3   10.075379  11.443909    9.994986   10.719042   11.899702   11.290874
# 4    8.395629   7.737834    7.366862    8.589320    6.281333    5.322718
# 5   47.190126  39.473054   41.674097   37.666890   45.890843   46.145882
#
#            19          20          21          22         23
# 0  250.259949  155.644429  162.116530  115.005100  72.086270
# 1   14.264426   11.844534    4.785737    5.568888   7.439510
# 2  123.056763  108.426198   86.447719   62.161339  62.647331
# 3   11.027765    9.313176   11.923023    9.327450   8.292606
# 4    9.517189    7.568386    7.087605    6.628476   6.192361
# 5   48.597645   49.983295   44.101949   43.506739  47.813743

# %%
APPLIANCE_ORDER
# Out:
# ['use',
#  'air1',
#  'dishwasher1',
#  'furnace1',
#  'kitchenapp1',
#  'microwave1',
#  'refrigerator1']

# %%
fig, ax = plt.subplots(ncols=6, figsize=(30, 3))
for u, appliance in enumerate(APPLIANCE_ORDER[1:]):
    appliance_num = APPLIANCE_ORDER.index(appliance)-1
    re = p.mean(axis=0).iloc[appliance_num]
    ac = pd.DataFrame(active_error).iloc[appliance_num]
    pd.DataFrame({"Random":re, "Active":ac}).plot(kind='bar',ax=ax[u], title=appliance,
                                                  yerr =[np.zeros_like(ac), p.std(axis=0).iloc[appliance_num]], rot=0)
fig.text(0.5, 0, "Month")
ax[0].set_ylabel("MAE \nLower is better")
plt.savefig("comparison-active.pdf")
plt.savefig("comparison-active.png")

# %%
from IPython.display import Image
Image('comparison-active.png')

# %%
chosen_homes = {12:[(5357, 'refrigerator1'), (5357, 'dishwasher1'), (4336, 'kitchenapp1'), (4336, 'air1'), (5357, 'microwave1')],
               13:[(3916, 'air1'), (7016, 'furnace1'), (5357, 'kitchenapp1'), (7719, 'refrigerator1'), (4154, 'air1')],
               14:[(2365, 'refrigerator1'), (4375, 'microwave1'), (2365, 'furnace1'), (7719, 'air1'), (4375, 'kitchenapp1')],
               15:[(1700, 'dishwasher1'), (7719, 'furnace1'), (1700, 'microwave1'), (3918, 'furnace1'), (3918, 'kitchenapp1')],
               16: [(1700, 'kitchenapp1'), (5357, 'air1'), (7719, 'dishwasher1'), (2018, 'air1'), (5357, 'furnace1')],
               17: [(7719, 'microwave1'), (2365, 'air1'), (484, 'dishwasher1'), (3044, 'kitchenapp1'), (1790, 'kitchenapp1')],
               18:[(2018, 'dishwasher1'), (7016, 'refrigerator1'), (4957, 'refrigerator1'), (4375, 'refrigerator1'), (3039, 'dishwasher1')],
               19:[(5972, 'refrigerator1'), (5972, 'air1'), (484, 'refrigerator1'), (6691, 'microwave1'), (484, 'air1')],
               20:[(3039, 'furnace1'), (1507, 'kitchenapp1'), (7719, 'kitchenapp1'), (7793, 'furnace1'), (6691, 'kitchenapp1')],
               21:[(4154, 'kitchenapp1'), (3916, 'kitchenapp1'), (3918, 'air1'), (3039, 'kitchenapp1'), (1790, 'air1')],
               22:[(7016, 'air1'), (1507, 'air1'), (3039, 'refrigerator1'), (4767, 'air1'), (1700, 'furnace1')],
               23:[(2018, 'refrigerator1'), (7793, 'refrigerator1'), (5972, 'furnace1'), (3044, 'refrigerator1'), (3039, 'air1')]}

# %%
homes = chosen_homes[x][
# Out:
#   File "<ipython-input-28-defaef61a8b1>", line 1
#     homes = chosen_homes[x][
#                             ^
# SyntaxError: unexpected EOF while parsing

# %%
pd.Series([x[0] for x in chosen_homes[12]]).value_counts()
# Out:
# 5357    3
# 4336    2
# dtype: int64

# %%
all_homes = np.array([[x[0] for x in chosen_homes[m]] for m in range(13, 24)]).flatten()

# %%
pd.Series(all_homes).value_counts().plot(kind='bar')

# %%
np.searchsorted(use_homes, 7719)
# Out:
# 152

# %%
pd.DataFrame(t[152, :, :]).iloc[2].plot()

# %%
p_m_h[13]
# Out:
# [(499, 'air1'),
#  (499, 'furnace1'),
#  (499, 'kitchenapp1'),
#  (499, 'refrigerator1'),
#  (503, 'air1'),
#  (503, 'dishwasher1'),
#  (503, 'furnace1'),
#  (503, 'kitchenapp1'),
#  (503, 'microwave1'),
#  (503, 'refrigerator1'),
#  (744, 'air1'),
#  (781, 'air1'),
#  (781, 'dishwasher1'),
#  (781, 'furnace1'),
#  (781, 'kitchenapp1'),
#  (781, 'microwave1'),
#  (781, 'refrigerator1'),
#  (871, 'air1'),
#  (871, 'dishwasher1'),
#  (871, 'furnace1'),
#  (871, 'kitchenapp1'),
#  (871, 'microwave1'),
#  (871, 'refrigerator1'),
#  (974, 'air1'),
#  (1086, 'air1'),
#  (1086, 'dishwasher1'),
#  (1086, 'furnace1'),
#  (1086, 'microwave1'),
#  (1086, 'refrigerator1'),
#  (1103, 'air1'),
#  (1169, 'air1'),
#  (1169, 'dishwasher1'),
#  (1169, 'furnace1'),
#  (1169, 'kitchenapp1'),
#  (1169, 'microwave1'),
#  (1169, 'refrigerator1'),
#  (1192, 'air1'),
#  (1202, 'air1'),
#  (1202, 'dishwasher1'),
#  (1202, 'furnace1'),
#  (1415, 'air1'),
#  (1415, 'dishwasher1'),
#  (1415, 'furnace1'),
#  (1415, 'kitchenapp1'),
#  (1415, 'microwave1'),
#  (1415, 'refrigerator1'),
#  (1500, 'air1'),
#  (1500, 'dishwasher1'),
#  (1500, 'furnace1'),
#  (1500, 'kitchenapp1'),
#  (1500, 'microwave1'),
#  (1500, 'refrigerator1'),
#  (1507, 'air1'),
#  (1507, 'dishwasher1'),
#  (1507, 'furnace1'),
#  (1507, 'kitchenapp1'),
#  (1507, 'microwave1'),
#  (1507, 'refrigerator1'),
#  (1632, 'air1'),
#  (1632, 'dishwasher1'),
#  (1632, 'furnace1'),
#  (1632, 'kitchenapp1'),
#  (1632, 'microwave1'),
#  (1632, 'refrigerator1'),
#  (1718, 'air1'),
#  (1800, 'air1'),
#  (1953, 'air1'),
#  (1953, 'furnace1'),
#  (1953, 'refrigerator1'),
#  (2129, 'air1'),
#  (2156, 'air1'),
#  (2156, 'dishwasher1'),
#  (2156, 'furnace1'),
#  (2156, 'microwave1'),
#  (2156, 'refrigerator1'),
#  (2171, 'air1'),
#  (2171, 'dishwasher1'),
#  (2171, 'furnace1'),
#  (2171, 'kitchenapp1'),
#  (2171, 'microwave1'),
#  (2171, 'refrigerator1'),
#  (2199, 'air1'),
#  (2199, 'dishwasher1'),
#  (2199, 'furnace1'),
#  (2199, 'refrigerator1'),
#  (2378, 'air1'),
#  (2378, 'furnace1'),
#  (2378, 'refrigerator1'),
#  (2472, 'air1'),
#  (2472, 'dishwasher1'),
#  (2472, 'furnace1'),
#  (2472, 'kitchenapp1'),
#  (2532, 'air1'),
#  (2532, 'dishwasher1'),
#  (2532, 'furnace1'),
#  (2532, 'microwave1'),
#  (7641, 'air1'),
#  (7641, 'dishwasher1'),
#  (7641, 'furnace1'),
#  (7641, 'kitchenapp1'),
#  (7641, 'microwave1'),
#  (7641, 'refrigerator1'),
#  (7731, 'air1'),
#  (7769, 'air1'),
#  (7769, 'dishwasher1'),
#  (7769, 'refrigerator1'),
#  (7787, 'air1'),
#  (7787, 'furnace1'),
#  (7787, 'microwave1'),
#  (7787, 'refrigerator1'),
#  (7788, 'air1'),
#  (7788, 'dishwasher1'),
#  (7788, 'furnace1'),
#  (7788, 'refrigerator1'),
#  (7850, 'air1'),
#  (7850, 'dishwasher1'),
#  (7850, 'furnace1'),
#  (7850, 'kitchenapp1'),
#  (7850, 'microwave1'),
#  (7850, 'refrigerator1'),
#  (7875, 'air1'),
#  (7875, 'furnace1'),
#  (7875, 'microwave1'),
#  (7875, 'refrigerator1'),
#  (7900, 'air1'),
#  (7940, 'air1'),
#  (7940, 'dishwasher1'),
#  (7940, 'furnace1'),
#  (7940, 'kitchenapp1'),
#  (7940, 'microwave1'),
#  (7940, 'refrigerator1'),
#  (7951, 'air1'),
#  (7951, 'dishwasher1'),
#  (7951, 'furnace1'),
#  (7951, 'kitchenapp1'),
#  (7951, 'microwave1'),
#  (7951, 'refrigerator1'),
#  (7973, 'air1'),
#  (7989, 'air1'),
#  (7989, 'furnace1'),
#  (7989, 'microwave1'),
#  (8046, 'air1'),
#  (8046, 'dishwasher1'),
#  (8046, 'furnace1'),
#  (8046, 'kitchenapp1'),
#  (8046, 'microwave1'),
#  (8046, 'refrigerator1'),
#  (8059, 'air1'),
#  (8059, 'dishwasher1'),
#  (8059, 'furnace1'),
#  (8059, 'kitchenapp1'),
#  (8059, 'microwave1'),
#  (8059, 'refrigerator1'),
#  (8079, 'air1'),
#  (8079, 'dishwasher1'),
#  (8079, 'furnace1'),
#  (8079, 'kitchenapp1'),
#  (8079, 'microwave1'),
#  (8079, 'refrigerator1'),
#  (8084, 'air1')]

# %%
{x:len(p_m_h[x]) for x in p_m_h.keys()}
# Out:
# {12: 361,
#  13: 361,
#  14: 361,
#  15: 361,
#  16: 361,
#  17: 361,
#  18: 356,
#  19: 356,
#  20: 356,
#  21: 356,
#  22: 356,
#  23: 352}

# %%
np.isfinite(t[:, 2:, -1].flatten()).sum()
# Out:
# 366

# %%
p_m_h = {}
for month in range(23, 24):
    p_m_h[month] = []
    for home in pool_homes:
        print(home)
        for i, appliance in enumerate(APPLIANCE_ORDER[1:]):
            pool_home_index  = np.searchsorted(use_homes, home)
            if np.isfinite(t[pool_home_index, i+1, month]):
                p_m_h[month].append((home, appliance))
# Out:
# 484
# 499
# 503
# 545
# 624
# 744
# 781
# 871
# 946
# 974
# 1086
# 1103
# 1169
# 1192
# 1202
# 1283
# 1403
# 1415
# 1463
# 1500
# 1507
# 1589
# 1617
# 1632
# 1642
# 1697
# 1700
# 1718
# 1790
# 1800
# 1953
# 2018
# 2094
# 2129
# 2156
# 2171
# 2199
# 2233
# 2365
# 2378
# 2472
# 2532
# 2557
# 2575
# 2638
# 2755
# 2787
# 2814
# 2818
# 2829
# 2859
# 2945
# 2953
# 2965
# 3009
# 3039
# 3044
# 3134
# 3268
# 3310
# 3367
# 3392
# 3456
# 3482
# 3500
# 3527
# 3538
# 3577
# 3649
# 3778
# 3829
# 3831
# 3849
# 3916
# 3918
# 3935
# 3967
# 4031
# 4154
# 4213
# 4220
# 4297
# 4298
# 4336
# 4342
# 4352
# 4357
# 4373
# 4375
# 4473
# 4514
# 4641
# 4767
# 4874
# 4946
# 4957
# 4998
# 5026
# 5060
# 5129
# 5218
# 5275
# 5317
# 5357
# 5403
# 5545
# 5568
# 5677
# 5718
# 5785
# 5809
# 5814
# 5874
# 5889
# 5921
# 5949
# 5959
# 5972
# 6061
# 6063
# 6121
# 6139
# 6165
# 6348
# 6412
# 6423
# 6460
# 6498
# 6691
# 6692
# 6730
# 6990
# 7016
# 7030
# 7361
# 7390
# 7429
# 7504
# 7536
# 7560
# 7627
# 7641
# 7719
# 7731
# 7769
# 7787
# 7788
# 7793
# 7850
# 7875
# 7900
# 7901
# 7940
# 7951
# 7973
# 7989
# 8046
# 8059
# 8079
# 8084

# %%
len(pool_homes)
# Out:
# 160

# %%
pool_home_index
# Out:
# 169

# %%
np.searchsorted(use_homes, 8084)
# Out:
# 169

# %%
np.isfinite(t[pool_home_index, i+1, month])
# Out:
# False

# %%
t[169, 1].shape
# Out:
# (24,)

# %%
np.isfinite(t[169].flatten()).sum()
# Out:
# 48

# %%
p_m_h
# Out:
# {23: [(499, 'air1'),
#   (499, 'furnace1'),
#   (499, 'kitchenapp1'),
#   (499, 'refrigerator1'),
#   (503, 'air1'),
#   (503, 'dishwasher1'),
#   (503, 'furnace1'),
#   (503, 'kitchenapp1'),
#   (503, 'microwave1'),
#   (503, 'refrigerator1'),
#   (744, 'air1'),
#   (781, 'air1'),
#   (781, 'dishwasher1'),
#   (781, 'furnace1'),
#   (781, 'kitchenapp1'),
#   (781, 'microwave1'),
#   (781, 'refrigerator1'),
#   (871, 'air1'),
#   (871, 'dishwasher1'),
#   (871, 'furnace1'),
#   (871, 'kitchenapp1'),
#   (871, 'microwave1'),
#   (871, 'refrigerator1'),
#   (974, 'air1'),
#   (1086, 'air1'),
#   (1086, 'dishwasher1'),
#   (1086, 'furnace1'),
#   (1086, 'microwave1'),
#   (1086, 'refrigerator1'),
#   (1103, 'air1'),
#   (1169, 'air1'),
#   (1169, 'dishwasher1'),
#   (1169, 'furnace1'),
#   (1169, 'kitchenapp1'),
#   (1169, 'microwave1'),
#   (1169, 'refrigerator1'),
#   (1192, 'air1'),
#   (1202, 'air1'),
#   (1202, 'dishwasher1'),
#   (1202, 'furnace1'),
#   (1415, 'air1'),
#   (1415, 'dishwasher1'),
#   (1415, 'furnace1'),
#   (1415, 'kitchenapp1'),
#   (1415, 'microwave1'),
#   (1415, 'refrigerator1'),
#   (1500, 'air1'),
#   (1500, 'dishwasher1'),
#   (1500, 'furnace1'),
#   (1500, 'kitchenapp1'),
#   (1500, 'microwave1'),
#   (1500, 'refrigerator1'),
#   (1507, 'air1'),
#   (1507, 'dishwasher1'),
#   (1507, 'furnace1'),
#   (1507, 'kitchenapp1'),
#   (1507, 'microwave1'),
#   (1507, 'refrigerator1'),
#   (1632, 'air1'),
#   (1632, 'dishwasher1'),
#   (1632, 'furnace1'),
#   (1632, 'kitchenapp1'),
#   (1632, 'microwave1'),
#   (1632, 'refrigerator1'),
#   (1718, 'air1'),
#   (1800, 'air1'),
#   (1953, 'air1'),
#   (1953, 'furnace1'),
#   (1953, 'refrigerator1'),
#   (2129, 'air1'),
#   (2156, 'air1'),
#   (2156, 'dishwasher1'),
#   (2156, 'furnace1'),
#   (2156, 'microwave1'),
#   (2156, 'refrigerator1'),
#   (2171, 'air1'),
#   (2171, 'dishwasher1'),
#   (2171, 'furnace1'),
#   (2171, 'kitchenapp1'),
#   (2171, 'microwave1'),
#   (2171, 'refrigerator1'),
#   (2199, 'air1'),
#   (2199, 'dishwasher1'),
#   (2199, 'furnace1'),
#   (2199, 'refrigerator1'),
#   (2378, 'air1'),
#   (2378, 'furnace1'),
#   (2378, 'refrigerator1'),
#   (2472, 'air1'),
#   (2472, 'dishwasher1'),
#   (2472, 'furnace1'),
#   (2472, 'kitchenapp1'),
#   (2532, 'air1'),
#   (2532, 'dishwasher1'),
#   (2532, 'furnace1'),
#   (2532, 'microwave1'),
#   (2532, 'refrigerator1'),
#   (2557, 'air1'),
#   (2557, 'furnace1'),
#   (2557, 'refrigerator1'),
#   (2638, 'air1'),
#   (2814, 'air1'),
#   (2814, 'dishwasher1'),
#   (2814, 'furnace1'),
#   (2814, 'microwave1'),
#   (2814, 'refrigerator1'),
#   (2859, 'air1'),
#   (2859, 'dishwasher1'),
#   (2859, 'furnace1'),
#   (2859, 'kitchenapp1'),
#   (2859, 'microwave1'),
#   (2859, 'refrigerator1'),
#   (2953, 'air1'),
#   (2953, 'refrigerator1'),
#   (2965, 'air1'),
#   (2965, 'dishwasher1'),
#   (2965, 'furnace1'),
#   (2965, 'kitchenapp1'),
#   (2965, 'microwave1'),
#   (2965, 'refrigerator1'),
#   (3009, 'air1'),
#   (3134, 'air1'),
#   (3310, 'air1'),
#   (3367, 'air1'),
#   (3367, 'dishwasher1'),
#   (3367, 'furnace1'),
#   (3367, 'microwave1'),
#   (3367, 'refrigerator1'),
#   (3392, 'furnace1'),
#   (3392, 'kitchenapp1'),
#   (3392, 'microwave1'),
#   (3392, 'refrigerator1'),
#   (3482, 'air1'),
#   (3482, 'dishwasher1'),
#   (3482, 'furnace1'),
#   (3482, 'microwave1'),
#   (3482, 'refrigerator1'),
#   (3500, 'air1'),
#   (3500, 'dishwasher1'),
#   (3500, 'furnace1'),
#   (3500, 'microwave1'),
#   (3500, 'refrigerator1'),
#   (3527, 'air1'),
#   (3649, 'air1'),
#   (3649, 'furnace1'),
#   (3649, 'refrigerator1'),
#   (3778, 'air1'),
#   (3778, 'furnace1'),
#   (3829, 'air1'),
#   (3831, 'air1'),
#   (3831, 'dishwasher1'),
#   (3831, 'kitchenapp1'),
#   (6165, 'refrigerator1'),
#   (6412, 'air1'),
#   (6423, 'air1'),
#   (6460, 'air1'),
#   (6460, 'dishwasher1'),
#   (6460, 'furnace1'),
#   (6460, 'kitchenapp1'),
#   (6460, 'microwave1'),
#   (6460, 'refrigerator1'),
#   (6691, 'air1'),
#   (6691, 'furnace1'),
#   (6691, 'refrigerator1'),
#   (7016, 'air1'),
#   (7016, 'dishwasher1'),
#   (7016, 'furnace1'),
#   (7016, 'kitchenapp1'),
#   (7016, 'microwave1'),
#   (7016, 'refrigerator1'),
#   (7030, 'air1'),
#   (7361, 'air1'),
#   (7361, 'furnace1'),
#   (7361, 'microwave1'),
#   (7429, 'air1'),
#   (7504, 'air1'),
#   (7504, 'dishwasher1'),
#   (7560, 'air1'),
#   (7560, 'furnace1'),
#   (7560, 'kitchenapp1'),
#   (7560, 'microwave1'),
#   (7560, 'refrigerator1'),
#   (7627, 'air1'),
#   (7627, 'dishwasher1'),
#   (7627, 'furnace1'),
#   (7627, 'kitchenapp1'),
#   (7627, 'microwave1'),
#   (7627, 'refrigerator1'),
#   (7641, 'air1'),
#   (7641, 'dishwasher1'),
#   (7641, 'furnace1'),
#   (7641, 'kitchenapp1'),
#   (7641, 'microwave1'),
#   (7641, 'refrigerator1'),
#   (7731, 'air1'),
#   (7769, 'air1'),
#   (7769, 'dishwasher1'),
#   (7769, 'refrigerator1'),
#   (7787, 'air1'),
#   (7787, 'furnace1'),
#   (7787, 'microwave1'),
#   (7787, 'refrigerator1'),
#   (7788, 'air1'),
#   (7788, 'dishwasher1'),
#   (7788, 'furnace1'),
#   (7788, 'refrigerator1'),
#   (7850, 'air1'),
#   (7850, 'dishwasher1'),
#   (7850, 'furnace1'),
#   (7850, 'kitchenapp1'),
#   (7850, 'microwave1'),
#   (7850, 'refrigerator1'),
#   (7875, 'air1'),
#   (7875, 'furnace1'),
#   (7875, 'microwave1'),
#   (7875, 'refrigerator1'),
#   (7900, 'air1'),
#   (7940, 'air1'),
#   (7940, 'dishwasher1'),
#   (7940, 'furnace1'),
#   (7940, 'kitchenapp1'),
#   (7940, 'microwave1'),
#   (7940, 'refrigerator1'),
#   (7951, 'air1'),
#   (7951, 'dishwasher1'),
#   (7951, 'furnace1'),
#   (7951, 'kitchenapp1'),
#   (7951, 'microwave1'),
#   (7951, 'refrigerator1'),
#   (7973, 'air1'),
#   (7989, 'air1'),
#   (7989, 'furnace1'),
#   (7989, 'microwave1'),
#   (8046, 'air1'),
#   (8046, 'dishwasher1'),
#   (8046, 'furnace1'),
#   (8046, 'kitchenapp1'),
#   (8046, 'microwave1'),
#   (8046, 'refrigerator1'),
#   (8059, 'air1'),
#   (8059, 'dishwasher1'),
#   (8059, 'furnace1'),
#   (8059, 'kitchenapp1'),
#   (8059, 'microwave1'),
#   (8059, 'refrigerator1'),
#   (8079, 'air1'),
#   (8079, 'dishwasher1'),
#   (8079, 'furnace1'),
#   (8079, 'kitchenapp1'),
#   (8079, 'microwave1'),
#   (8079, 'refrigerator1'),
#   (8084, 'air1')]}
